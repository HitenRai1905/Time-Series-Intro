# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Alcohol_Sales.csv',index_col='DATE',parse_dates=True)
df.index.freq = 'MS'

# %%
df.head()
# Out:
#             S4248SM144NCEN
# DATE
# 1992-01-01            3459
# 1992-02-01            3458
# 1992-03-01            4002
# 1992-04-01            4564
# 1992-05-01            4221

# %%
df.columns = ['Sales']
df.plot(figsize = (12,8))
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
from pmdarima import auto_arima
stepwise_fit = auto_arima(df['Sales'],trace =True,
                          suppress_warnings=True)           

stepwise_fit.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.36 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=5581.852, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=5521.140, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=5399.757, Time=0.11 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=5579.946, Time=0.01 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=5400.180, Time=0.21 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=5399.909, Time=0.25 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.29 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=5427.084, Time=0.04 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0] intercept
# Total fit time: 1.297 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                  325
# Model:               SARIMAX(0, 1, 1)   Log Likelihood               -2696.878
# ...

# %%
df['Sale_LastMonth']=df['Sales'].shift(+1)
df['Sale_2Monthsback']=df['Sales'].shift(+2)
df['Sale_3Monthsback']=df['Sales'].shift(+3)
df
# Out:
#             Sales  Sale_LastMonth  Sale_2Monthsback  Sale_3Monthsback
# DATE
# 1992-01-01   3459             NaN               NaN               NaN
# 1992-02-01   3458          3459.0               NaN               NaN
# 1992-03-01   4002          3458.0            3459.0               NaN
# 1992-04-01   4564          4002.0            3458.0            3459.0
# 1992-05-01   4221          4564.0            4002.0            3458.0
# ...           ...             ...               ...               ...
# 2018-09-01  12396         14257.0           12640.0           14583.0
# 2018-10-01  13914         12396.0           14257.0           12640.0
# 2018-11-01  14174         13914.0           12396.0           14257.0
# 2018-12-01  15504         14174.0           13914.0           12396.0
# 2019-01-01  10718         15504.0           14174.0           13914.0
#
# [325 rows x 4 columns]

# %%
df=df.dropna()
df
# Out:
#             Sales  Sale_LastMonth  Sale_2Monthsback  Sale_3Monthsback
# DATE
# 1992-04-01   4564          4002.0            3458.0            3459.0
# 1992-05-01   4221          4564.0            4002.0            3458.0
# 1992-06-01   4529          4221.0            4564.0            4002.0
# 1992-07-01   4466          4529.0            4221.0            4564.0
# 1992-08-01   4137          4466.0            4529.0            4221.0
# ...           ...             ...               ...               ...
# 2018-09-01  12396         14257.0           12640.0           14583.0
# 2018-10-01  13914         12396.0           14257.0           12640.0
# 2018-11-01  14174         13914.0           12396.0           14257.0
# 2018-12-01  15504         14174.0           13914.0           12396.0
# 2019-01-01  10718         15504.0           14174.0           13914.0
#
# [322 rows x 4 columns]

# %%
from sklearn.linear_model import LinearRegression
lin_model=LinearRegression()

# %%
from sklearn.ensemble import RandomForestRegressor
model=RandomForestRegressor(n_estimators=100,max_features=3, random_state=1)

# %%
x1 = df['Sale_LastMonth']
x2 = df['Sale_2Monthsback']
x3 = df['Sale_3Monthsback']
y = df['Sales']


#convert into numpy array
x1 = np.array(x1)
x2 = np.array(x2)
x3 = np.array(x3)
y=np.array(y)



#reshape the array

x1 = x1.reshape(-1,1)#-1->row i.e we donot care how many rows are;1-> col
x2 = x2.reshape(-1,1)
x3 = x3.reshape(-1,1)
y  = y.reshape(-1,1)


#concatenate x1,x2,x3 to form final_x
final_x=np.concatenate((x1,x2,x3),axis=1)#x1 x2 x3
print(final_x)
# Out:
# [[ 4002.  3458.  3459.]
#  [ 4564.  4002.  3458.]
#  [ 4221.  4564.  4002.]
#  [ 4529.  4221.  4564.]
#  [ 4466.  4529.  4221.]
#  [ 4137.  4466.  4529.]
#  [ 4126.  4137.  4466.]
#  [ 4259.  4126.  4137.]
#  [ 4240.  4259.  4126.]
#  [ 4936.  4240.  4259.]
#  [ 3031.  4936.  4240.]
#  [ 3261.  3031.  4936.]
#  [ 4160.  3261.  3031.]
#  [ 4377.  4160.  3261.]
#  [ 4307.  4377.  4160.]
#  [ 4696.  4307.  4377.]
#  [ 4458.  4696.  4307.]
#  [ 4457.  4458.  4696.]
#  [ 4364.  4457.  4458.]
#  [ 4236.  4364.  4457.]
#  [ 4500.  4236.  4364.]
#  [ 4974.  4500.  4236.]
#  [ 3075.  4974.  4500.]
#  [ 3377.  3075.  4974.]
#  [ 4443.  3377.  3075.]
#  [ 4261.  4443.  3377.]
#  [ 4460.  4261.  4443.]
#  [ 4985.  4460.  4261.]
#  [ 4324.  4985.  4460.]
#  [ 4719.  4324.  4985.]
#  [ 4374.  4719.  4324.]
#  [ 4248.  4374.  4719.]
#  [ 4784.  4248.  4374.]
#  [ 4971.  4784.  4248.]
#  [ 3370.  4971.  4784.]
#  [ 3484.  3370.  4971.]
#  [ 4269.  3484.  3370.]
#  [ 3994.  4269.  3484.]
# ...

# %%
X_train,X_test,y_train,y_test=final_x[:-30],final_x[-30:],y[:-30],y[-30:]

# %%
model.fit(X_train,y_train)
lin_model.fit(X_train,y_train)
# Out:
# C:\Users\vostr\AppData\Local\Temp/ipykernel_3596/1977262272.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(X_train,y_train)
# LinearRegression()

# %%
pred = model.predict(X_test)

import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (12,8)
plt.plot(pred,label='Random_Forest_Predictions')
plt.plot(y_test,label='Actual Sales')
plt.legend(loc="upper left")
plt.show()

# %%
pred1 = lin_model.predict(X_test)

import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (12,8)
plt.plot(pred1,label='Linear_Regression_Predictions')
plt.plot(y_test,label='Actual Sales')
plt.legend(loc="upper left")
plt.show()

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
rmse_rf=sqrt(mean_squared_error(pred,y_test))
rmse_lr=sqrt(mean_squared_error(pred1,y_test))

# %%
print('Mean Squared Error for Random Forest Model is:',rmse_rf)
print('Mean Squared Error for Linear Regression Model is:',rmse_lr)
# Out:
# Mean Squared Error for Random Forest Model is: 1913.7762399350665
# Mean Squared Error for Linear Regression Model is: 1791.4965232759828

# %% [markdown]
# You just need to have input and ouput col and then you can use any regression model
